# %%
import pandas as pd

weather = pd.read_csv("data.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                                               NAME  \
# DATE
# 1970-01-01  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-02  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-03  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-04  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-05  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# ...                 ...                                                ...
# 2022-07-09  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-10  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-11  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-12  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-13  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
#
#             PRCP  SNOW  SNWD   TMAX  TMIN
# DATE
# 1970-01-01  0.00   0.0   0.0   34.0  24.0
# 1970-01-02  0.00   0.0   0.0   39.0  20.0
# 1970-01-03  0.02   0.0   0.0   36.0  25.0
# 1970-01-04  0.00   0.0   0.0   31.0  18.0
# 1970-01-05  0.00   0.0   0.0   43.0  16.0
# ...          ...   ...   ...    ...   ...
# 2022-07-09  0.00   NaN   NaN  100.0  67.0
# 2022-07-10  0.00   NaN   NaN  103.0  71.0
# 2022-07-11  0.00   NaN   NaN   84.0  63.0
# 2022-07-12  0.01   NaN   NaN   93.0  60.0
# 2022-07-13  0.00   NaN   NaN   99.0  61.0
#
# [38234 rows x 7 columns]

# %%
null_pct = weather.apply(pd.isnull).sum()/weather.shape[0]
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# PRCP       0.016294
# SNOW       0.246718
# SNWD       0.246090
# TMAX       0.001752
# TMIN       0.001779
# dtype: float64

# %%
weather.columns = weather.columns.str.lower()
weather
# Out:
#                 station                                               name  \
# DATE
# 1970-01-01  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-02  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-03  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-04  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-05  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# ...                 ...                                                ...
# 2022-07-09  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-10  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-11  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-12  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-13  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
#
#             prcp  snow  snwd   tmax  tmin
# DATE
# 1970-01-01  0.00   0.0   0.0   34.0  24.0
# 1970-01-02  0.00   0.0   0.0   39.0  20.0
# 1970-01-03  0.02   0.0   0.0   36.0  25.0
# 1970-01-04  0.00   0.0   0.0   31.0  18.0
# 1970-01-05  0.00   0.0   0.0   43.0  16.0
# ...          ...   ...   ...    ...   ...
# 2022-07-09  0.00   NaN   NaN  100.0  67.0
# 2022-07-10  0.00   NaN   NaN  103.0  71.0
# 2022-07-11  0.00   NaN   NaN   84.0  63.0
# 2022-07-12  0.01   NaN   NaN   93.0  60.0
# 2022-07-13  0.00   NaN   NaN   99.0  61.0
#
# [38234 rows x 7 columns]

# %%
weather = weather.ffill()
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.apply(lambda x: (x == 9999).sum())
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2022-07-04', '2022-07-05', '2022-07-06', '2022-07-07', '2022-07-08',
#        '2022-07-09', '2022-07-10', '2022-07-11', '2022-07-12', '2022-07-13'],
#       dtype='object', name='DATE', length=38234)

# %%
weather.index = pd.to_datetime(weather.index)
weather.index.year.value_counts().sort_index()
# Out:
# 1970    730
# 1971    730
# 1972    732
# 1973    730
# 1974    730
# 1975    730
# 1976    732
# 1977    730
# 1978    730
# 1979    730
# 1980    732
# 1981    730
# 1982    730
# 1983    730
# 1984    732
# 1985    730
# 1986    730
# 1987    730
# 1988    732
# 1989    730
# 1990    730
# 1991    730
# 1992    732
# 1993    730
# 1994    730
# 1995    730
# 1996    608
# 1997    725
# 1998    728
# 1999    730
# 2000    732
# 2001    730
# 2002    730
# 2003    730
# 2004    732
# 2005    730
# 2006    730
# 2007    730
# 2008    732
# 2009    729
# 2010    730
# 2011    729
# 2012    731
# 2013    730
# 2014    730
# 2015    728
# 2016    732
# 2017    730
# 2018    727
# 2019    730
# 2020    731
# 2021    730
# 2022    388
# Name: DATE, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <AxesSubplot: xlabel='DATE'>

# %%
weather["target"] = weather.shift(-1)["tmax"]
weather
# Out:
#                 station                                               name  \
# DATE
# 1970-01-01  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-02  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-03  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-04  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-05  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# ...                 ...                                                ...
# 2022-07-09  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-10  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-11  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-12  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-13  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
#
#             prcp  snow  snwd   tmax  tmin  target
# DATE
# 1970-01-01  0.00   0.0   0.0   34.0  24.0    39.0
# 1970-01-02  0.00   0.0   0.0   39.0  20.0    36.0
# 1970-01-03  0.02   0.0   0.0   36.0  25.0    31.0
# 1970-01-04  0.00   0.0   0.0   31.0  18.0    43.0
# 1970-01-05  0.00   0.0   0.0   43.0  16.0    40.0
# ...          ...   ...   ...    ...   ...     ...
# 2022-07-09  0.00   0.0   0.0  100.0  67.0   103.0
# 2022-07-10  0.00   0.0   0.0  103.0  71.0    84.0
# 2022-07-11  0.00   0.0   0.0   84.0  63.0    93.0
# 2022-07-12  0.01   0.0   0.0   93.0  60.0    99.0
# 2022-07-13  0.00   0.0   0.0   99.0  61.0     NaN
#
# [38234 rows x 8 columns]

# %%
weather = weather.ffill()

# %%
weather
# Out:
#                 station                                               name  \
# DATE
# 1970-01-01  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-02  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-03  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-04  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1970-01-05  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# ...                 ...                                                ...
# 2022-07-09  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-10  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-11  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-12  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 2022-07-13  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
#
#             prcp  snow  snwd   tmax  tmin  target
# DATE
# 1970-01-01  0.00   0.0   0.0   34.0  24.0    39.0
# 1970-01-02  0.00   0.0   0.0   39.0  20.0    36.0
# 1970-01-03  0.02   0.0   0.0   36.0  25.0    31.0
# 1970-01-04  0.00   0.0   0.0   31.0  18.0    43.0
# 1970-01-05  0.00   0.0   0.0   43.0  16.0    40.0
# ...          ...   ...   ...    ...   ...     ...
# 2022-07-09  0.00   0.0   0.0  100.0  67.0   103.0
# 2022-07-10  0.00   0.0   0.0  103.0  71.0    84.0
# 2022-07-11  0.00   0.0   0.0   84.0  63.0    93.0
# 2022-07-12  0.01   0.0   0.0   93.0  60.0    99.0
# 2022-07-13  0.00   0.0   0.0   99.0  61.0    99.0
#
# [38234 rows x 8 columns]

# %%
from sklearn.linear_model import Ridge

rr = Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
def backtest(weather, model, predictors, start=3650, step=90):
    all_predictions = []
    
    for i in range(start, weather.shape[0], step):
        train = weather.iloc[:i,:]
        test = weather.iloc[i:(i+step),:]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        combined["diff"] = (combined["prediction"] - combined["actual"]).abs()
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(weather, rr, predictors)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 7.111283462839401

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2000-04-14    27.0   96.375971  69.375971
# 2022-07-13    27.0   89.923609  62.923609
# 1996-02-29    92.0   39.635710  52.364290
# 2000-11-12    73.0   23.967113  49.032887
# 2000-04-13   122.0   74.424496  47.575504
# ...            ...         ...        ...
# 1986-03-04    48.0   48.002980   0.002980
# 1980-02-12    41.0   41.001795   0.001795
# 1997-05-13    73.0   73.000578   0.000578
# 2006-08-26    87.0   87.000560   0.000560
# 1991-06-11    88.0   87.999882   0.000118
#
# [34584 rows x 3 columns]

# %%
pd.Series(rr.coef_, index=predictors)
# Out:
# prcp   -2.810265
# snow   -0.496113
# snwd   -0.002275
# tmax    0.667245
# tmin    0.266117
# dtype: float64

# %%
def pct_diff(old, new):
    return (new - old) / old

def compute_rolling(weather, horizon, col):
    label = f"rolling_{horizon}_{col}"
    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] = pct_diff(weather[label], weather[col])
    return weather
    
rolling_horizons = [3, 14]
for horizon in rolling_horizons:
    for col in ["tmax", "tmin", "prcp"]:
        weather = compute_rolling(weather, horizon, col)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

# %%
mean_absolute_error(predictions["actual"], predictions["prediction"])
# Out:
# 7.111283462839401

# %%
weather = weather.iloc[14:,:]
weather = weather.fillna(0)

# %%
predictors = weather.columns[~weather.columns.isin(["target", "name", "station"])]

# %%
predictions.sort_values("diff", ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2000-04-14    27.0   96.375971  69.375971
# 2022-07-13    27.0   89.923609  62.923609
# 1996-02-29    92.0   39.635710  52.364290
# 2000-11-12    73.0   23.967113  49.032887
# 2000-04-13   122.0   74.424496  47.575504
# ...            ...         ...        ...
# 1986-03-04    48.0   48.002980   0.002980
# 1980-02-12    41.0   41.001795   0.001795
# 1997-05-13    73.0   73.000578   0.000578
# 2006-08-26    87.0   87.000560   0.000560
# 1991-06-11    88.0   87.999882   0.000118
#
# [34584 rows x 3 columns]

# %%
mean_squared_error(predictions["actual"], predictions["prediction"])
# Out:
# 82.5510951730512

# %%
weather.loc["1990-03-07": "1990-03-17"]
# Out:
#                 station                                               name  \
# DATE
# 1990-03-07  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-08  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-09  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-10  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-11  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-12  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-13  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-14  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-15  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-16  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-17  USW00093721  BALTIMORE WASHINGTON INTERNATIONAL AIRPORT, MD US
# 1990-03-07  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 1990-03-08  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 1990-03-09  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 1990-03-10  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 1990-03-11  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 1990-03-12  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 1990-03-13  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 1990-03-14  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 1990-03-15  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 1990-03-16  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
# 1990-03-17  USW00024015                 AKRON WASHINGTON CO AIRPORT, CO US
#
#             prcp  snow  snwd  tmax  tmin  target  rolling_3_tmax  \
# DATE
# 1990-03-07  0.00   0.0   0.0  37.0  20.0    48.0       44.666667
# 1990-03-08  0.00   0.0   0.0  48.0  18.0    62.0       43.666667
# 1990-03-09  0.02   0.0   0.0  62.0  32.0    61.0       49.000000
# 1990-03-10  0.00   0.0   0.0  61.0  43.0    68.0       57.000000
# 1990-03-11  0.00   0.0   0.0  68.0  43.0    86.0       63.666667
# 1990-03-12  0.00   0.0   0.0  86.0  49.0    85.0       71.666667
# 1990-03-13  0.00   0.0   0.0  85.0  60.0    81.0       79.666667
